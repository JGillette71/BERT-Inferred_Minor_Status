# %% [markdown]
# <a href="https://colab.research.google.com/github/JGillette71/BERT-Inferred_Minor_Status/blob/main/Storyteller_Data_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Global Giving Storytelling Project Data Exploration
#
# NER Research Project
#
# Jason Gillette
#
# Source: https://data.world/marcmaxmeister/globalgiving-storytelling-project
#
# Tasks
#   - [x] Read data file
#   - [x] Summary Stats
#   - [x] Remove entries with insufficient length
#   - [x] Clean leading or trailing whitespace
#   - [x] General NER analysis via BERT
#     - [x] export copy
#   - [ ] Remove entries w/o sufficient entities
#   - [ ] Automated spelling corrections???
#   - [ ] Publish cleaned data for custom entity tagging

# %%
import pandas as pd

# %%
# read data 
data = pd.read_csv('/content/drive/MyDrive/Grad School Projects /globalgiving-storytelling-project-QueryResult.csv')
data.head()
# Out:
#           created_date                                              story  \
# 0  2011-04-07T07:08:59  Many people in different countries have been k...
# 1  2011-04-29T06:03:22  - In Kenya many people died because of violenc...
# 2  2011-04-29T11:25:59  An organization known as the 'VMS' meaning vol...
# 3  2011-05-16T04:19:16  Safaricom is one of the leading telecommunicat...
# 4  2011-07-16T18:40:36  politics and development are things that go ha...
#
#    storyteller_age_lt_16  storyteller_gender_f  storyteller_gender_m  \
# 0                      0                     0                     1
# 1                      0                     1                     0
# 2                      0                     0                     1
# 3                      0                     0                     0
# 4                      0                     1                     0
#
#                         title         organization_name  \
# 0            Anominous Felony                      JUNK
# 1                    Violence               people died
# 2      UNPLEASING PERSONALITY       VOLUNTEER MINISTERS
# 3  Interaction through sports  SAFARICOM MOBILE NETWORK
# 4            political absurd                individual
#
#   revised_organization_name story_location_country story_location_city  \
# 0                      None                  Kenya             Nairobi
# 1                      None                  KENYA             NAIROBI
# 2       Volunteer Ministers                  KENYA             NAIROBI
# 3         Safaricom Company                  KENYA             NAIROBI
# 4                Individual                  Kenya            kakamega
#
#   story_location_neighborhood  latitude  longitude  \
# 0                   Kibera 42 -1.318426  36.796496
# 1          Kibera D.C /kianda -1.133330  34.550000
# 2         SCOUT CAMP ROWALAND -1.133330  34.550000
# 3               KIBERA MAKINA -1.318426  36.796496
# 4                     intisia  0.266750  34.894390
#
#                                      location
# 0  POINT(36.79649600000000 -1.31842600000000)
# 1  POINT(34.55000000000000 -1.13333000000000)
# 2  POINT(34.55000000000000 -1.13333000000000)
# 3  POINT(36.79649600000000 -1.31842600000000)
# 4   POINT(34.89439000000000 0.26675000000000)

# %%
# check schema and size 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57818 entries, 0 to 57817
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   created_date                 57818 non-null  object
#  1   story                        57818 non-null  object
#  2   storyteller_age_lt_16        57818 non-null  int64
#  3   storyteller_gender_f         57818 non-null  int64
#  4   storyteller_gender_m         57818 non-null  int64
#  5   title                        57660 non-null  object
#  6   organization_name            57438 non-null  object
#  7   revised_organization_name    33072 non-null  object
#  8   story_location_country       56985 non-null  object
#  9   story_location_city          56788 non-null  object
#  10  story_location_neighborhood  55680 non-null  object
#  11  latitude                     38521 non-null  float64
#  12  longitude                    38521 non-null  float64
#  13  location                     38521 non-null  object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 6.2+ MB

# %% [markdown]
# 'created_date' --> date story was recorded
#
# **'story' --> target text**
#
# **'storyteller_age_lt_16' --> Is the storyteller under 16 y.o.**
#
# 'storyteller_gender_f' --> storyteller_gender
#
# 'storyteller_gender_m' --> storyteller_gender
#
# 'title' --> topic?
#
# 'organization_name' -->
#
# 'revised_organization_name' -->
#
# 'story_location_country'  --> country
#
# 'story_location_city'  --> city
#
# 'story_location_neighborhood'  --> neighborhood
#
# 'latitude' --> loc data
#
# 'longitude' --> loc data
#
# 'location' --> loc data

# %%
# counts if the storyteller is under 16 years old 
print('values counts:')
print(data['storyteller_age_lt_16' ].value_counts())
print('percentage:')
print(data['storyteller_age_lt_16' ].value_counts(normalize=True))
# Out:
# values counts:
# 0    52087
# 1     5731
# Name: storyteller_age_lt_16, dtype: int64
# percentage:
# 0    0.900879
# 1    0.099121
# Name: storyteller_age_lt_16, dtype: float64

# %% [markdown]
# Roughly 10% of entries are stories told by minors, indicative of minor entity type in associated stories, but not necessarily the case for each.

# %%
# create column w/ story length 
data['avg_story_length'] = data['story'].apply(lambda x: len(x.split()))
print(data['avg_story_length'].head())
print(data['avg_story_length'].describe())
# Out:
# 0     68
# 1     90
# 2    135
# 3    133
# 4     64
# Name: avg_story_length, dtype: int64
# count    57818.000000
# mean        69.378308
# std         36.909739
# min          1.000000
# 25%         42.000000
# 50%         61.000000
# 75%         88.000000
# max        592.000000
# Name: avg_story_length, dtype: float64

# %%
# how many stories have over 512 words
# BERT cannot accept over 512 tokens; sentences get truncated 
data[data['avg_story_length'] > 500]
# Out:
#               created_date                                              story  \
# 29095  2012-03-18T22:21:23  I’m writing this letter to share with everyone...
#
#        storyteller_age_lt_16  storyteller_gender_f  storyteller_gender_m  \
# 29095                      0                     0                     1
#
#                                                    title  \
# 29095  Hope for our children. How our community was t...
#
#               organization_name revised_organization_name  \
# 29095  Sumando Manos Foundation                       NaN
#
#       story_location_country story_location_city  \
# 29095              Argentina            Misiones
#
#                           story_location_neighborhood  latitude  longitude  \
# 29095  El Soberbio, El Boton. La Flor. School #  269        NaN        NaN
#
#       location  avg_story_length
# 29095      NaN               592

# %%
# how many stories have low word counts / unlikely to contain contextual training value 
data[data['avg_story_length'] < 10]
# Out:
#               created_date                                              story  \
# 33728  2012-07-09T07:21:35  You understand about food security we are wish...
# 33872  2012-07-09T09:07:56          How about the support from outside?thanks
# 33890  2012-07-09T11:04:55   Who best assists the poor. \r\n\r\nCare Inter...
# 34443  2012-07-10T07:21:22   Proudly we need your support.Thanks. Kibera Y...
# 44705  2011-06-13T20:44:38  mrembo program educated me about adolescence,p...
# 46359  2012-12-19T08:16:34                                                 ..
# 46362  2012-12-19T08:27:19                                                ...
# 46379  2012-12-20T05:12:46                                                  .
# 46380  2012-12-20T05:14:25                 After the post election violence..
# 46386  2012-12-20T06:51:43                                                  .
# 46387  2012-12-20T06:54:09                                               The
# 46389  2012-12-20T07:10:29                                                  .
# 46390  2012-12-20T07:12:17                                                  .
# 46394  2012-12-20T07:44:54                                                 ..
# 46397  2012-12-20T08:28:42                                                  .
# 46401  2012-12-20T08:53:23                                                 ..
# 46402  2012-12-20T08:57:26                                                  .
# 46418  2012-12-21T05:37:57                                                  .
# 46424  2012-12-21T07:11:54                                                  .
# 46436  2012-12-24T02:33:14                                                  .
# 46568  2012-12-24T06:23:56                                            Ochieng
# 46652  2012-12-24T08:51:17   The Luo Community don't circumcise according to
# 47187  2012-12-27T03:06:13                                                  .
# 47229  2012-12-27T03:41:12                                                 ..
# 47258  2012-12-27T04:03:19                                                  .
# 47271  2012-12-27T04:11:48                                                  .
# 47309  2012-12-27T05:04:15                                                  .
# 47346  2012-12-27T06:37:39                                                  .
# 47349  2012-12-27T06:39:11                                                  .
# 47386  2012-12-27T08:06:23                                                 ..
# 47398  2012-12-27T08:29:26                                                 ..
# 47418  2012-12-27T08:59:40                                                  .
# 47464  2012-12-28T01:48:45                                                  B
# 47520  2012-12-28T03:42:59                                                  .
# 47568  2012-12-28T04:42:09                                                  .
# 47620  2012-12-28T06:34:05                                                  .
# 47663  2012-12-28T07:59:28            ....JKKLKKJKHYU67777777GHG GFRWEEQWWBHG
# 48499  2013-01-02T01:42:29                                                  .
# 48582  2013-01-02T03:43:39                                                  G
# 48584  2013-01-02T03:46:59                                                  ,
# 48942  2013-01-03T02:51:22                                                  .
# 49061  2013-01-03T04:33:43                                                 ..
# 49148  2013-01-03T05:32:03                                                  .
# 49507  2013-01-04T05:29:38                                                  .
# 49738  2013-01-07T06:12:34                                                 ..
# 49795  2013-01-08T07:55:15                                                 ..
# 49797  2013-01-08T08:48:51                                           My aunt
# 49799  2013-01-08T08:59:10                                                  ,
# 49828  2013-01-09T08:14:01    I.M.F is an organisation which is international
# 49829  2013-01-09T08:30:18                                     nvgf rbhhh  5t
# 49885  2013-01-14T07:13:30                                               RHFD
# 49886  2013-01-14T07:15:53                                                J87
# 49892  2013-01-14T08:47:22                                                  H
# 50002  2013-01-16T08:54:03                                               jjgc
# 50027  2013-01-17T04:12:33                                          lkiooouiy
# 50035  2013-01-17T05:12:45                                               ggtt
# 50037  2013-01-17T07:42:06        One teacher in our school helped one school
# 50042  2013-01-18T02:41:02                                                 yf
#
#        storyteller_age_lt_16  storyteller_gender_f  storyteller_gender_m  \
# 33728                      0                     0                     1
# 33872                      0                     0                     0
# 33890                      0                     0                     0
# 34443                      0                     0                     1
# 44705                      0                     1                     0
# 46359                      0                     0                     1
# 46362                      0                     0                     1
# 46379                      0                     0                     1
# 46380                      0                     0                     0
# 46386                      0                     0                     0
# 46387                      0                     0                     1
# 46389                      0                     0                     1
# 46390                      0                     0                     1
# 46394                      0                     0                     0
# 46397                      0                     0                     0
# 46401                      0                     0                     1
# 46402                      0                     0                     0
# 46418                      0                     0                     0
# 46424                      0                     0                     0
# 46436                      0                     0                     1
# 46568                      0                     0                     1
# 46652                      0                     0                     1
# 47187                      0                     0                     1
# 47229                      0                     0                     1
# 47258                      0                     0                     1
# 47271                      0                     0                     1
# 47309                      0                     0                     1
# 47346                      0                     0                     1
# 47349                      0                     0                     1
# 47386                      0                     0                     1
# 47398                      0                     0                     1
# 47418                      0                     0                     1
# 47464                      0                     1                     0
# 47520                      0                     0                     1
# 47568                      0                     0                     1
# 47620                      0                     1                     0
# 47663                      0                     0                     1
# 48499                      0                     0                     1
# 48582                      0                     0                     1
# 48584                      0                     1                     0
# 48942                      0                     0                     1
# 49061                      0                     0                     1
# 49148                      0                     0                     1
# 49507                      0                     0                     1
# 49738                      0                     0                     1
# 49795                      0                     0                     1
# 49797                      0                     0                     1
# 49799                      0                     0                     1
# 49828                      0                     0                     1
# 49829                      0                     0                     1
# 49885                      0                     1                     0
# 49886                      0                     1                     0
# 49892                      0                     1                     0
# 50002                      0                     0                     0
# 50027                      0                     1                     0
# 50035                      0                     0                     0
# 50037                      0                     1                     0
# 50042                      0                     1                     0
#
#                         title             organization_name  \
# 33728                    Food            Care International
# 33872                  Thanks            care international
# 33890                Priority            Care International
# 34443               Is it you                  World Vision
# 44705    Orphans in kamukunji                mrembo program
# 46359     IN PURSUE FOR PEACE                   AMANI KENYA
# 46362      IMPROVING HYGIENE            KISUMU TOWN WELFARE
# 46379                       .                             .
# 46380                       .                             .
# 46386                       .                             .
# 46387  DRUG FREE IINSTITUTION             YOUTH FRESH KENYA
# 46389                       .                             .
# 46390                       .                             .
# 46394                      ..                           ...
# 46397                       .                             .
# 46401                       .                             .
# 46402                       .                             .
# 46418                       .                             .
# 46424                       .                             .
# 46436                       .                             .
# 46568         AFTER THE REHAB                    INDIVIDUAL
# 46652                       ,                             ,
# 47187                       .                             .
# 47229                       ,                             .
# 47258                       .                             .
# 47271                       .                             .
# 47309                       .                             .
# 47346                       .                             .
# 47349                       .                             .
# 47386                       .                             .
# 47398                       .                             .
# 47418                       .                             .
# 47464       THE CANCER AFFAIR        ROCKEFELLER FOUNDATION
# 47520                       .                             .
# 47568                       .                             .
# 47620                       .                             .
# 47663                      GH                            GG
# 48499                       .                             .
# 48582                      GF                            DG
# 48584                       ,                             ,
# 48942                       .                             .
# 49061              Midwifery                     individual
# 49148                       .                             .
# 49507                       .                             .
# 49738     THE MUNGIKI MENACE   MURANG'A WOMEN WELFARE GROUP
# 49795                       .                             .
# 49797            encouraging                            mtg
# 49799                       ,                           NaN
# 49828      CHECK OF INFLATION                         I.M.F
# 49829                      gr                          rbh
# 49885                     Z23                          Z\DS
# 49886                       U                            56
# 49892                     GHH                             N
# 50002                     hdf                          gdfg
# 50027                   yuity                          tr 3
# 50035                       .                             .
# 50037  The crying school girl                    individual
# 50042                     re4                            54
#
#       revised_organization_name story_location_country story_location_city  \
# 33728                       NaN                  Kenya             Nairobi
# 33872                       NaN                  Kenya             Nairobi
# 33890                       NaN                  Kenya             Nairobi
# 34443                       NaN                  Kenya             Nairobi
# 44705            Mrembo Program                  KENYE             NAIROBI
# 46359                       NaN                 KENYA               KISUMU
# 46362                       NaN                 KENYA               KISUMU
# 46379                       NaN                 KENYA              NAIROBI
# 46380                       NaN                    NaN                 NaN
# 46386                       NaN                    NaN                 NaN
# 46387                       NaN                 KENYA                THIKA
# 46389                       NaN                 KENYA              NAIROBI
# 46390                       NaN                 KENYA              NAIROBI
# 46394                       NaN                    NaN                 NaN
# 46397                       NaN                    NaN                 NaN
# 46401                       NaN                 KENYA                SIAYA
# 46402                       NaN                    NaN                 NaN
# 46418                       NaN                 KENYA                SIAYA
# 46424                       NaN                    NaN                 NaN
# 46436                       NaN                 KENYA               KISUMU
# 46568                       NaN                 KENYA                SIAYA
# 46652                       NaN                 KENYA               KISUMU
# 47187                       NaN                 KENYA                SIAYA
# 47229                       NaN                 KENYA               KISUMU
# 47258                       NaN                 KENYA              ELDORET
# 47271                       NaN                 KENYA                SIAYA
# 47309                       NaN                 KENYA              NAIROBI
# 47346                       NaN                 KENYA               KISUMU
# 47349                       NaN                 KENYA                SIAYA
# 47386                       NaN                 KENYA              NAIROBI
# 47398                       NaN                 KENYA                SIAYA
# 47418                       NaN                 KENYA               NAKURU
# 47464                       NaN                 KENYA             HOMA BAY
# 47520                       NaN                 KENYA              NANYUKI
# 47568                       NaN                 KENYA                SIAYA
# 47620                       NaN                 KENYA              ELDORET
# 47663                       NaN                 KENYA              NAIROBI
# 48499                       NaN                 KENYA             NYATIKE
# 48582                       NaN                 KENYA                BUSIA
# 48584                       NaN                 KENYA              NAIROBI
# 48942                       NaN                 KENYA                SIAYA
# 49061                       NaN                 KENYA                SIAYA
# 49148                       NaN                 KENYA              KISAUNI
# 49507                       NaN                 KENYA              NAIROBI
# 49738                       NaN                 KENYA             MURANG'A
# 49795                       NaN                 KENYA                SIAYA
# 49797                       NaN                 KENYA              MOMBASA
# 49799                       NaN                 KENYA                SIAYA
# 49828                       NaN                UGANDA             KAMPALA
# 49829                       NaN                UGANDA             KAMPALA
# 49885                       NaN                UGANDA             KAMPALA
# 49886                       NaN                UGANDA             KAMPALA
# 49892                       NaN                UGANDA             KAMPALA
# 50002                       NaN                    NaN                 NaN
# 50027                       NaN                UGANDA             KAMPALA
# 50035                       NaN                    NaN                 NaN
# 50037                       NaN                UGANDA             KAMPALA
# 50042                       NaN                UGANDA             KAMPALA
#
#               story_location_neighborhood  latitude  longitude  \
# 33728                              Ngando       NaN        NaN
# 33872                              Ngando       NaN        NaN
# 33890                        Nairobi Slum       NaN        NaN
# 34443                              Kibera       NaN        NaN
# 44705                            muthurua  -1.13333      34.55
# 46359                         KISUMU TOWN       NaN        NaN
# 46362                            NYALENDA       NaN        NaN
# 46379                       MASIMBA STAGE       NaN        NaN
# 46380                                 NaN       NaN        NaN
# 46386                                 NaN       NaN        NaN
# 46387                                 NaN       NaN        NaN
# 46389                            MATHARE        NaN        NaN
# 46390                            MATHARE        NaN        NaN
# 46394                                 NaN       NaN        NaN
# 46397                                 NaN       NaN        NaN
# 46401       SIAYA TOWNSHIP PRIMARY SCHOOL       NaN        NaN
# 46402                                 NaN       NaN        NaN
# 46418                              KAREMO       NaN        NaN
# 46424                                 NaN       NaN        NaN
# 46436                       LAKE VICTORIA       NaN        NaN
# 46568              MBAGA MIXED DAY SCHOOL       NaN        NaN
# 46652           NEW NYANZA DISTRICT HOSP.       NaN        NaN
# 47187                         EQUITY BANK       NaN        NaN
# 47229                         KISUMU TOWN       NaN        NaN
# 47258                              HURUMA       NaN        NaN
# 47271                          SIAYA TOWN       NaN        NaN
# 47309                      AGA KHAN HOSP.       NaN        NaN
# 47346                               AYANY       NaN        NaN
# 47349                             RANDAGO       NaN        NaN
# 47386                          UHURU PARK       NaN        NaN
# 47398                               AGORO       NaN        NaN
# 47418                               LANET       NaN        NaN
# 47464                              MIGORI       NaN        NaN
# 47520                    MT. KENYA FOREST       NaN        NaN
# 47568                                ROCK       NaN        NaN
# 47620                              HURUMA       NaN        NaN
# 47663                             NGEI II       NaN        NaN
# 48499                              RABUOR       NaN        NaN
# 48582                           BUDALANGI       NaN        NaN
# 48584                          STRATHMORE       NaN        NaN
# 48942                              KOGELO       NaN        NaN
# 49061                       ALEGO- ASUMBI       NaN        NaN
# 49148  SHIMO LA TEWA PRISON -MALINDI ROAD       NaN        NaN
# 49507                       KAYOLE-SOWETO       NaN        NaN
# 49738                      MURANG'A TOWN        NaN        NaN
# 49795                         BONDO ROUTE       NaN        NaN
# 49797                              KILIFI       NaN        NaN
# 49799                ASERE PRIMARY SCHOOL       NaN        NaN
# 49828                               KATWE       NaN        NaN
# 49829                              MAGETA       NaN        NaN
# 49885                            MUTUNDWE       NaN        NaN
# 49886                              WAZANA       NaN        NaN
# 49892                               KATWE       NaN        NaN
# 50002                                 NaN       NaN        NaN
# 50027                              UGUNJA       NaN        NaN
# 50035                                 NaN       NaN        NaN
# 50037                               KATWE       NaN        NaN
# 50042                               KATWE       NaN        NaN
#
#                                          location  avg_story_length
# 33728                                         NaN                 9
# 33872                                         NaN                 6
# 33890                                         NaN                 7
# 34443                                         NaN                 9
# 44705  POINT(34.55000000000000 -1.13333000000000)                 8
# 46359                                         NaN                 1
# 46362                                         NaN                 1
# 46379                                         NaN                 1
# 46380                                         NaN                 5
# 46386                                         NaN                 1
# 46387                                         NaN                 1
# 46389                                         NaN                 1
# 46390                                         NaN                 1
# 46394                                         NaN                 1
# 46397                                         NaN                 1
# 46401                                         NaN                 1
# 46402                                         NaN                 1
# 46418                                         NaN                 1
# 46424                                         NaN                 1
# 46436                                         NaN                 1
# 46568                                         NaN                 1
# 46652                                         NaN                 7
# 47187                                         NaN                 1
# 47229                                         NaN                 1
# 47258                                         NaN                 1
# 47271                                         NaN                 1
# 47309                                         NaN                 1
# 47346                                         NaN                 1
# 47349                                         NaN                 1
# 47386                                         NaN                 1
# 47398                                         NaN                 1
# 47418                                         NaN                 1
# 47464                                         NaN                 1
# 47520                                         NaN                 1
# 47568                                         NaN                 1
# 47620                                         NaN                 1
# 47663                                         NaN                 2
# 48499                                         NaN                 1
# 48582                                         NaN                 1
# 48584                                         NaN                 1
# 48942                                         NaN                 1
# 49061                                         NaN                 1
# 49148                                         NaN                 1
# 49507                                         NaN                 1
# 49738                                         NaN                 1
# 49795                                         NaN                 1
# 49797                                         NaN                 2
# 49799                                         NaN                 1
# 49828                                         NaN                 7
# 49829                                         NaN                 3
# 49885                                         NaN                 1
# 49886                                         NaN                 1
# 49892                                         NaN                 1
# 50002                                         NaN                 1
# 50027                                         NaN                 1
# 50035                                         NaN                 1
# 50037                                         NaN                 8
# 50042                                         NaN                 1

# %% [markdown]
# Begin cleaning up the data

# %%
# arbitrary 10% buffer for max len and min word count of 10 words
data = data[(data['avg_story_length'] < 460) & (data['avg_story_length'] > 10)]
data.reset_index(inplace=True)
print(len(data))
print(data['avg_story_length'].describe())
# Out:
# 57755
# count    57755.000000
# mean        69.433157
# std         36.765103
# min         11.000000
# 25%         42.000000
# 50%         61.000000
# 75%         88.000000
# max        459.000000
# Name: avg_story_length, dtype: float64

# %% [markdown]
# Dropped about 58 entries

# %%
# clean leading non alphabetic chars or whitespace and trailing whitespace from stories using regex 
import re 
data['story'] = data['story'].replace(r"^[^a-zA-Z]+| +$", r"", regex=True)
data['story']
# Out:
# 0        Many people in different countries have been k...
# 1        In Kenya many people died because of violence,...
# 2        An organization known as the 'VMS' meaning vol...
# 3        Safaricom is one of the leading telecommunicat...
# 4        politics and development are things that go ha...
#                                ...
# 57750    Fighting among children in a responsive charac...
# 57751    corruption in our communities is like a diseas...
# 57752    Its adevelopmental small metre finnechel busin...
# 57753    Samaritan blinds an individual growth healthwi...
# 57754    Considered as the earliest kind of business in...
# Name: story, Length: 57755, dtype: object

# %%
# fix missing spaces after periods and commas
data['story'] = data['story'].replace(r'(?<=[.,])(?=[^\s])', r' ', regex=True)
# See "whole of Africa.it" for confirmation of correction
data.at[3, 'story']
# Out:
# 'Safaricom is one of the leading telecommunication network company in the whole of Africa. it has over a billion subscriber and half of them are enrolled members to its savings branch.\r\nSafaricom was established over five years ago and has managed to be the best and mobile phone subscriber and has managed to be the best and most profitable business firm in east and central Africa\r\nThey saw the need of helping the community rather than being a service provider alone and taking away peoples money. So the came to the community and organised and funded sporting tournaments for the youth and it was a very successful idea\r\nWinners were awarded and also the loosers were never left out. It also proved to be an important tool to the company the organisationand started using its services.'

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.17.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.49)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.11.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.63.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.7.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)

# %%
# example token classification to identify general entities 
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy='simple')
example = data.at[3, 'story'] 

ner_results = nlp(example)
print(len(example.split()))
print(example)
print(ner_results)
# Out:
# 136
# Safaricom is one of the leading telecommunication network company in the whole of Africa. it has over a billion subscriber and half of them are enrolled members to its savings branch.
# Safaricom was established over five years ago and has managed to be the best and mobile phone subscriber and has managed to be the best and most profitable business firm in east and central Africa
# They saw the need of helping the community rather than being a service provider alone and taking away peoples money. So the came to the community and organised and funded sporting tournaments for the youth and it was a very successful idea
# Winners were awarded and also the loosers were never left out. It also proved to be an important tool to the company the organisationand started using its services.
# [{'entity_group': 'ORG', 'score': 0.9977357, 'word': 'Safaricom', 'start': 0, 'end': 9}, {'entity_group': 'LOC', 'score': 0.9996039, 'word': 'Africa', 'start': 82, 'end': 88}, {'entity_group': 'ORG', 'score': 0.99321526, 'word': 'Safaricom', 'start': 185, 'end': 194}, {'entity_group': 'LOC', 'score': 0.99962044, 'word': 'Africa', 'start': 375, 'end': 381}]

# %%
# split with regex instead of .split() to seperate punctuation like the tokenizer 
# not needed here, may need for later token alignment 
split = re.findall(r"[\w']+|[.,!?;]", example)
print(len(split))
print(split)
# Out:
# 141
# ['Safaricom', 'is', 'one', 'of', 'the', 'leading', 'telecommunication', 'network', 'company', 'in', 'the', 'whole', 'of', 'Africa', '.', 'it', 'has', 'over', 'a', 'billion', 'subscriber', 'and', 'half', 'of', 'them', 'are', 'enrolled', 'members', 'to', 'its', 'savings', 'branch', '.', 'Safaricom', 'was', 'established', 'over', 'five', 'years', 'ago', 'and', 'has', 'managed', 'to', 'be', 'the', 'best', 'and', 'mobile', 'phone', 'subscriber', 'and', 'has', 'managed', 'to', 'be', 'the', 'best', 'and', 'most', 'profitable', 'business', 'firm', 'in', 'east', 'and', 'central', 'Africa', 'They', 'saw', 'the', 'need', 'of', 'helping', 'the', 'community', 'rather', 'than', 'being', 'a', 'service', 'provider', 'alone', 'and', 'taking', 'away', 'peoples', 'money', '.', 'So', 'the', 'came', 'to', 'the', 'community', 'and', 'organised', 'and', 'funded', 'sporting', 'tournaments', 'for', 'the', 'youth', 'and', 'it', 'was', 'a', 'very', 'successful', 'idea', 'Winners', 'were', 'awarded', 'and', 'also', 'the', 'loosers', 'were', 'never', 'left', 'out', '.', 'It', 'also', 'proved', 'to', 'be', 'an', 'important', 'tool', 'to', 'the', 'company', 'the', 'organisationand', 'started', 'using', 'its', 'services', '.']

# %%
# !pip install swifter
# Out:
# Requirement already satisfied: swifter in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.9.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.63.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.1.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (21.3)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.5)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2022.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.1.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.9.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (4.11.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (3.10.0.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.0.0->swifter) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (0.2.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (22.3.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach>=3.1.1->swifter) (3.0.7)

# %%
import swifter
# Swifter automatically decides which is faster: Dask parallel processing or Pandas apply.

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")
nlp = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy='simple')

# id general entities in all stories 
data['entities'] = data['story'].swifter.apply(lambda x: nlp(x))

data['entities']
# Out:
# Pandas Apply:   0%|          | 0/57755 [00:00<?, ?it/s]
# 0        [{'entity_group': 'MISC', 'score': 0.99714357,...
# 1        [{'entity_group': 'LOC', 'score': 0.9998136, '...
# 2        [{'entity_group': 'ORG', 'score': 0.76395184, ...
# 3        [{'entity_group': 'ORG', 'score': 0.9977357, '...
# 4                                                       []
#                                ...
# 57750    [{'entity_group': 'ORG', 'score': 0.9783759, '...
# 57751    [{'entity_group': 'ORG', 'score': 0.77378774, ...
# 57752    [{'entity_group': 'MISC', 'score': 0.9950283, ...
# 57753    [{'entity_group': 'ORG', 'score': 0.5690524, '...
# 57754    [{'entity_group': 'MISC', 'score': 0.995856, '...
# Name: entities, Length: 57755, dtype: object

# %%
data.at[0, 'entities']
# Out:
# [{'end': 245,
#   'entity_group': 'MISC',
#   'score': 0.99714357,
#   'start': 242,
#   'word': 'HIV'},
#  {'end': 250,
#   'entity_group': 'MISC',
#   'score': 0.7982759,
#   'start': 246,
#   'word': 'AIDS'}]

# %%
def extract_entity_groups(i):
  return([dictionary['entity_group'] for dictionary in i if 'entity_group' in dictionary])

data['entities'] = data['entities'].swifter.apply(lambda x: extract_entity_groups(x))

data['entities']
# Out:
# Pandas Apply:   0%|          | 0/57755 [00:00<?, ?it/s]
# 0                   [MISC, MISC]
# 1              [LOC, MISC, MISC]
# 2                          [ORG]
# 3           [ORG, LOC, ORG, LOC]
# 4                             []
#                   ...
# 57750                 [ORG, ORG]
# 57751                      [ORG]
# 57752               [MISC, MISC]
# 57753                      [ORG]
# 57754    [MISC, MISC, ORG, MISC]
# Name: entities, Length: 57755, dtype: object

# %% [markdown]
# ### NER Analysis Checkpoint

# %%
# export data so I don't have to run nlp pipeline again 
data.to_csv('/content/drive/MyDrive/Grad School Projects /storytelling-ner-added.csv')

# %%
# read saved data 
data = pd.read_csv('/content/drive/MyDrive/Grad School Projects /storytelling-ner-added.csv')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57755 entries, 0 to 57754
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   57755 non-null  int64
#  1   index                        57755 non-null  int64
#  2   created_date                 57755 non-null  object
#  3   story                        57755 non-null  object
#  4   storyteller_age_lt_16        57755 non-null  int64
#  5   storyteller_gender_f         57755 non-null  int64
#  6   storyteller_gender_m         57755 non-null  int64
#  7   title                        57597 non-null  object
#  8   organization_name            57376 non-null  object
#  9   revised_organization_name    33069 non-null  object
#  10  story_location_country       56930 non-null  object
#  11  story_location_city          56733 non-null  object
#  12  story_location_neighborhood  55626 non-null  object
#  13  latitude                     38518 non-null  float64
#  14  longitude                    38518 non-null  float64
#  15  location                     38518 non-null  object
#  16  avg_story_length             57755 non-null  int64
#  17  entities                     57755 non-null  object
# dtypes: float64(2), int64(6), object(10)
# memory usage: 7.9+ MB

# %%
# convert entities column back to list type 
# csv import converts to string 
from ast import literal_eval

data['entities'] = data['entities'].apply(lambda x: literal_eval(x))

type(data.at[0,'entities'])
# Out:
# list

# %%
# average entities per story
print(data['entities'].apply(len).mean())

# max entities in stories  
print(data['entities'].apply(len).max())

# counts  
print(data['entities'].apply(len).value_counts())
# Out:
# 2.2076876460912476
# 34
# 0     14353
# 1     13364
# 2     10360
# 3      7165
# 4      4618
# 5      2961
# 6      1830
# 7      1101
# 8       733
# 9       426
# 10      290
# 11      192
# 12       99
# 13       86
# 14       53
# 15       37
# 16       25
# 17       16
# 20       11
# 18       10
# 19        7
# 21        4
# 26        4
# 22        3
# 28        2
# 25        2
# 23        1
# 27        1
# 34        1
# Name: entities, dtype: int64

# %%
# set arbitrary range for entity count per story 
clean_data = data[(data['entities'].map(len) > 5) & (data['entities'].map(len) < 21)]

# Need to reset index 
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4916 entries, 31 to 57746
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   4916 non-null   int64
#  1   index                        4916 non-null   int64
#  2   created_date                 4916 non-null   object
#  3   story                        4916 non-null   object
#  4   storyteller_age_lt_16        4916 non-null   int64
#  5   storyteller_gender_f         4916 non-null   int64
#  6   storyteller_gender_m         4916 non-null   int64
#  7   title                        4898 non-null   object
#  8   organization_name            4879 non-null   object
#  9   revised_organization_name    2969 non-null   object
#  10  story_location_country       4822 non-null   object
#  11  story_location_city          4796 non-null   object
#  12  story_location_neighborhood  4665 non-null   object
#  13  latitude                     3367 non-null   float64
#  14  longitude                    3367 non-null   float64
#  15  location                     3367 non-null   object
#  16  avg_story_length             4916 non-null   int64
#  17  entities                     4916 non-null   object
# dtypes: float64(2), int64(6), object(10)
# memory usage: 729.7+ KB

# %%
# count instances of each entity 
clean_data['entities'].explode().value_counts()
# Out:
# PER     11016
# LOC     10179
# ORG      9569
# MISC     7441
# Name: entities, dtype: int64

# %%
# count total entities  
clean_data['entities'].explode().count().sum()
# Out:
# 38205

# %%
final_cols = ['story',
              'storyteller_age_lt_16',
              'storyteller_gender_f',
              'storyteller_gender_m', 
              'story_location_country',
              'story_location_city',
              'entities']

clean_data = clean_data[final_cols]
clean_data.reset_index(drop=True, inplace=True)   
clean_data.head()
# Out:
#                                                story  storyteller_age_lt_16  \
# 0  The law should be amended to give the truth Ju...                      0
# 1  Baraka Youth Group in Emuhaya  District empowe...                      0
# 2  M-Learning is the short form of the word Mobil...                      0
# 3  It was one of those glorous evenings students ...                      1
# 4  Food donations by the Kenya Red Cross society ...                      0
#
#    storyteller_gender_f  storyteller_gender_m story_location_country  \
# 0                     1                     0                  KENYA
# 1                     0                     1                 kenya
# 2                     0                     1                  KENYA
# 3                     1                     0                  KENYA
# 4                     0                     1                  KENYA
#
#   story_location_city                                           entities
# 0            KAKAMEGA              [ORG, MISC, ORG, PER, PER, LOC, MISC]
# 1             Emuhaya  [ORG, LOC, PER, PER, ORG, MISC, MISC, LOC, PER...
# 2             NAIROBI                    [ORG, ORG, MISC, ORG, ORG, ORG]
# 3            KAKAMEGA                     [LOC, ORG, LOC, ORG, ORG, LOC]
# 4             NAIROBI               [ORG, LOC, LOC, ORG, MISC, LOC, LOC]

# %%
# export data so I don't have to run nlp pipeline again 
clean_data.to_csv('/content/drive/MyDrive/Grad School Projects /clean-storytelling-data.csv')

# %%
clean_data['story'] = clean_data['story'].replace(r'\t|\n|\r| | +', r' ', regex=True)

clean_data.head(10)
# Out:
#                                                story  storyteller_age_lt_16  \
# 0  The law should be amended to give the truth Ju...                      0
# 1  Baraka Youth Group in Emuhaya  District empowe...                      0
# 2  M-Learning is the short form of the word Mobil...                      0
# 3  It was one of those glorous evenings students ...                      1
# 4  Food donations by the Kenya Red Cross society ...                      0
# 5  Western HIV/AIDS Network - WEHAK- mainly a cap...                      0
# 6  Western HIV/AIDs Networking concentrates to HI...                      0
# 7  Western HIV/AIDS Network - WEHAK while working...                      0
# 8  Western HIV/AIDS Network- WEHAK Works with com...                      0
# 9  Our organisation- Western HIV/AIDS Network has...                      0
#
#    storyteller_gender_f  storyteller_gender_m story_location_country  \
# 0                     1                     0                  KENYA
# 1                     0                     1                 kenya
# 2                     0                     1                  KENYA
# 3                     1                     0                  KENYA
# 4                     0                     1                  KENYA
# 5                     0                     1                  KENYA
# 6                     1                     0                  Kenya
# 7                     1                     0                  KENYA
# 8                     1                     0                  KENYA
# 9                     1                     0                  KENYA
#
#   story_location_city                                           entities
# 0            KAKAMEGA              [ORG, MISC, ORG, PER, PER, LOC, MISC]
# 1             Emuhaya  [ORG, LOC, PER, PER, ORG, MISC, MISC, LOC, PER...
# 2             NAIROBI                    [ORG, ORG, MISC, ORG, ORG, ORG]
# 3            KAKAMEGA                     [LOC, ORG, LOC, ORG, ORG, LOC]
# 4             NAIROBI               [ORG, LOC, LOC, ORG, MISC, LOC, LOC]
# 5            KAKAMEGA  [ORG, MISC, ORG, MISC, ORG, ORG, ORG, ORG, ORG...
# 6            Kakamega                [MISC, MISC, MISC, ORG, MISC, MISC]
# 7            KAKAMEGA      [ORG, MISC, ORG, PER, MISC, MISC, MISC, MISC]
# 8            KAKAMEGA                  [ORG, MISC, ORG, MISC, ORG, MISC]
# 9            KAKAMEGA          [ORG, MISC, MISC, MISC, MISC, MISC, MISC]

# %%
# write curated stories to text file for use in annotation tool 
for chunk in chunksize:
clean_data['story'].to_csv('/content/drive/MyDrive/Grad School Projects /currated_story_data_chunk.txt', sep='\n', chunksize=1000, index=False) # this isn't correctly writing one line in file per entry

# %%
chunk_size = 100
counter = 0
for chunk in pd.read_csv("/content/drive/MyDrive/Grad School Projects /currated_story_data_onesep.txt", chunksize=100, sep='\n'):
  counter = counter + 1
  chunk.to_csv(f'/content/drive/MyDrive/Grad School Projects /ner_data/ner_data_chunk{counter}.txt',index=False)

# %%
filename = "/content/drive/MyDrive/Grad School Projects /currated_story_data_onesep.txt"

#w tells python we are opening the file to write into it
outfile = open(filename, 'w')

for story in clean_data['story']:
  outfile.write(story + "\n")

outfile.close() #Close the file when we’re done!

# %%
filename = '/content/drive/MyDrive/Grad School Projects /currated_story_data_chunk'+'A'+'.txt'
outfile = open(filename, 'w')
stop = i*500
for story in clean_data['story'][1:100]:
  outfile.write(story + "\n")
outfile.close()

# %%
for i in range(1,11):
  print(i*500)
# Out:
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000

# %%
clean_data[(clean_data['story'].str.contains(' '))&(clean_data['story'].str.contains('age'))]
# Out:
#                                                   story  \
# 1     Baraka Youth Group in Emuhaya  District empowe...
# 2     M-Learning is the short form of the word Mobil...
# 8     Western HIV/AIDS Network- WEHAK Works with com...
# 10    Water is the most precious commodity in the wo...
# 25    Twitter delivers a miracle for a family in nee...
# ...                                                 ...
# 4888  The formation of RIDOKAM self Help group in Ur...
# 4897  In Hamisi District, Western Kenya, there is a ...
# 4901  Unemployment is a key contributor to Kenya's p...
# 4906  Hillary Bilali is my name. I am a youth 17 yrs...
# 4912  Youth are the most powerful resource of any co...
#
#       storyteller_age_lt_16  storyteller_gender_f  storyteller_gender_m  \
# 1                         0                     0                     1
# 2                         0                     0                     1
# 8                         0                     1                     0
# 10                        0                     0                     1
# 25                        0                     0                     1
# ...                     ...                   ...                   ...
# 4888                      0                     0                     1
# 4897                      0                     0                     0
# 4901                      0                     0                     1
# 4906                      0                     0                     1
# 4912                      0                     0                     0
#
#      story_location_country story_location_city  \
# 1                    kenya              Emuhaya
# 2                     KENYA             NAIROBI
# 8                     KENYA            KAKAMEGA
# 10                    Kenya              Vihiga
# 25                    KENYA             NAIROBI
# ...                     ...                 ...
# 4888                  KENYA              MIGORI
# 4897                  KENYA            CHEPTULU
# 4901                  KENYA            CHEPTULU
# 4906                  Kenya            Kakamega
# 4912                  Kenya    KAKAMEGA CENTRAL
#
#                                                entities
# 1     [ORG, LOC, PER, PER, ORG, MISC, MISC, LOC, PER...
# 2                       [ORG, ORG, MISC, ORG, ORG, ORG]
# 8                     [ORG, MISC, ORG, MISC, ORG, MISC]
# 10                      [MISC, LOC, LOC, LOC, ORG, LOC]
# 25             [ORG, PER, PER, PER, LOC, LOC, PER, ORG]
# ...                                                 ...
# 4888                     [ORG, ORG, LOC, LOC, LOC, ORG]
# 4897                    [LOC, LOC, LOC, LOC, LOC, MISC]
# 4901      [LOC, LOC, LOC, LOC, LOC, PER, PER, PER, LOC]
# 4906     [PER, LOC, MISC, MISC, MISC, MISC, MISC, MISC]
# 4912                 [MISC, MISC, ORG, MISC, MISC, PER]
#
# [1460 rows x 7 columns]

# %%
per_count = 0
for i in range(len(clean_data)):
  if 'PER' in clean_data.at[i, 'entities']:
    per_count +=1
print(per_count)
# Out:
# 2754
